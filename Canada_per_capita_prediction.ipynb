# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model

# %%
df=pd.read_csv(r"C:\Users\farooq\Downloads\canada_per_capita_income.csv")
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
# %matplotlib inline
plt.xlabel('Year')
plt.ylabel('Per Capita income(in USD$)')
plt.scatter(df.year,df[['per capita income (US$)']],color='Blue',marker='.')

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['year']],df[['per capita income (US$)']])
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# C:\Users\farooq\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[41288.69409442]])

# %%
d= pd.DataFrame({'year':[2017,2018,2019,2020,2021,2022,2023,2024,2025]})

# %%
p=reg.predict(d)
p
# Out:
# array([[38803.29886875],
#        [39631.76394397],
#        [40460.22901919],
#        [41288.69409442],
#        [42117.15916964],
#        [42945.62424486],
#        [43774.08932009],
#        [44602.55439531],
#        [45431.01947053]])

# %%
d['per capita income (US$)'] = p

# %%
d
# Out:
#    year  per capita income (US$)
# 0  2017             38803.298869
# 1  2018             39631.763944
# 2  2019             40460.229019
# 3  2020             41288.694094
# 4  2021             42117.159170
# 5  2022             42945.624245
# 6  2023             43774.089320
# 7  2024             44602.554395
# 8  2025             45431.019471

# %%
final_data=df.merge(d,how='outer',on=['year','per capita income (US$)'])

# %%
final_data
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
# %matplotlib inline
plt.xlabel('Year')
plt.ylabel('Per Capita income(in USD$)')
plt.scatter(final_data.year,final_data[['per capita income (US$)']],color='Blue',marker='.')
plt.plot(final_data.year,reg.predict(final_data[['year']]),color='Red')
